# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 

from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
df= pd.read_csv (r'C:\Users\xps\Downloads\kc_house_data.csv',)
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df["date"].values[0]
# Out:
# '20141013T000000'

# %%
df["year"]=df["date"].apply(lambda x:int(x[0:4]))

# %%
df["day"]=df["date"].apply(lambda x:x[4:6])

# %%
df["month"]=df["date"].apply(lambda x:x[4:6])

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 0             1180      5650     1.0           0     0  ...      1955
# ...

# %%
df["day"]
# Out:
# 0        10
# 1        12
# 2        02
# 3        12
# 4        02
#          ..
# 21608    05
# 21609    02
# 21610    06
# 21611    01
# 21612    10
# Name: day, Length: 21613, dtype: object

# %%
df.to_csv('dataPreprocessed.csv')

# %%
def date (d,depart,arrive):
    df[d]= df["date"].apply(lambda x:int(x[depart:arrive]))
date("month",4,6)
date("day",6,8)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# bedrooms ; bathrooms ; sqft_living ; grade ; sqft_above ; sqft_living15

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('dataPreprocessed.csv')   
x=data[["bedrooms","bathrooms","sqft_living","grade","sqft_above","sqft_living15"]].values
xx = data["grade"].values
y=data["price"].values
linear_regressor = LinearRegression() 
linear_regressor.fit(x, y)   
y_pred = linear_regressor.predict(x)   
y_pred
# Out:
# array([305729.02610617, 578777.75428374, 195139.57807074, ...,
#        315019.280676  , 454323.59665425, 315019.280676  ])

# %%
plt.scatter(xx, y)
plt.plot(y, linear_regressor.predict(xx), color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-8adaa4a6dd53> in <module>
#       1 plt.scatter(xx, y)
# ----> 2 plt.plot(y, linear_regressor.predict(xx), color='red')
#       3 plt.show()
#
# ~\anaconda3\anaconda\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\anaconda\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     218         check_is_fitted(self)
#     219
# --> 220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#
# ...

# %%
x=data["sqft_living15"].values.reshape(-1,1)
y=data["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 93766676702.02818
# R squared 0.3504957439554969

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, predicted, color='red')
plt.show()

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 0             1180      5650     1.0           0     0  ...      1955
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('dataPreprocessed.csv')   
from sklearn.linear_model import LinearRegression
np.random.seed(0)
x=data["sqft_living15"].values.reshape(-1,1)
y=data["price"].values

x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-e4893932d336> in <module>
#      14
#      15 model = LinearRegression()
# ---> 16 model.fit(x, y)
#      17 y_pred = model.predict(x)
#      18
#
# ~\anaconda3\anaconda\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

x=data["sqft_living15"].values.reshape(-1,1)
y=data["price"].values

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.show()

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
data = pd.read_csv('dataPreprocessed.csv')   


np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

x=data[["bedrooms","bathrooms","sqft_living","grade","sqft_above","sqft_living15"]].values
xx = data["grade"].values
xx = data["grade"].values
y=data["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42) #splitting data with test size of 35%


polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print(rmse)
print(r2)
# Out:
# 224917.52090412984
# 0.6246524765118178

# %%
plt.scatter(x_train, y_test, s=10)
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x_train,  y_poly_pred, color='m')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-e83255639f72> in <module>
# ----> 1 plt.scatter(x_train, y_test, s=10)
#       2 sort_axis = operator.itemgetter(0)
#       3 sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
#       4 x, y_poly_pred = zip(*sorted_zip)
#       5 plt.plot(x_train,  y_poly_pred, color='m')
#
# ~\anaconda3\anaconda\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...
