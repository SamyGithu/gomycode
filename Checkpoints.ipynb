# %%
import pandas as pd
import numpy as np  


df = pd.read_csv (r'C:\Users\xps\Downloads\titanic-passengers.csv',
                 sep=";",)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
uniqueValues = df['Age'].unique()
print('Number of unique values in column "Age" including NaN')
print(uniqueValues)
# Out:
# Number of unique values in column "Age" including NaN
# [28.   25.   20.   29.   31.   37.   19.    1.   20.5  42.   24.   48.
#    nan 17.   27.   32.   38.   45.   30.5  41.   60.   50.   30.   40.
#  34.   36.    3.   16.    7.   23.   44.   70.5  22.   26.   35.    0.67
#  62.   43.   18.   33.    2.   39.   55.   56.   59.   58.   65.    9.
#  51.   54.   28.5  14.   13.   21.   46.    4.   49.   47.   74.   11.
#  36.5   6.   55.5  14.5   5.   32.5  15.    8.   57.   10.   40.5  34.5
#   0.75 64.   63.   61.   80.   24.5  66.    0.83 71.   45.5  52.   70.
#   0.92 53.    0.42 12.   23.5 ]

# %%
q = uniqueValues[12]

# %%
import math

math.isnan(q)
# Out:
# True

# %%
uniqueValues = df['Cabin'].unique()
print('Number of unique values in column "Cabin" including NaN')
print(uniqueValues)
# Out:
# Number of unique values in column "Cabin" including NaN
# [nan 'F G73' 'B71' 'C82' 'C93' 'B41' 'C95' 'B38' 'C52' 'A32' 'C111' 'C2'
#  'E101' 'D17' 'B22' 'B3' 'C45' 'B78' 'A31' 'C128' 'C30' 'A26' 'C22 C26'
#  'D15' 'T' 'C54' 'C103' 'C125' 'D20' 'C78' 'E24' 'B82 B84' 'E12' 'D9'
#  'D28' 'D19' 'G6' 'D48' 'C90' 'D56' 'E33' 'B86' 'F2' 'B77' 'B39' 'F33'
#  'D26' 'C85' 'A34' 'C92' 'F G63' 'D45' 'D' 'C91' 'B79' 'D21' 'C32' 'C83'
#  'C47' 'B58 B60' 'E38' 'B28' 'E58' 'A16' 'B20' 'C126' 'E77' 'B96 B98'
#  'C65' 'C123' 'C68' 'B35' 'B5' 'C46' 'E10' 'B51 B53 B55' 'E68' 'B49' 'B30'
#  'F E69' 'D10 D12' 'B57 B59 B63 B66' 'D11' 'D36' 'C99' 'D7' 'C23 C25 C27'
#  'C106' 'B19' 'C124' 'E8' 'A23' 'A10' 'E31' 'B73' 'B18' 'E46' 'D50' 'F38'
#  'B37' 'A7' 'A5' 'E67' 'D33' 'C118' 'C7' 'A36' 'C62 C64' 'E34' 'D6' 'A6'
#  'B101' 'E44' 'C70' 'A20' 'E121' 'C87' 'C50' 'B4' 'C104' 'C148' 'A14'
#  'B50' 'C110' 'D46' 'D35' 'B69' 'D49' 'E40' 'C101' 'D37' 'B102' 'E36'
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
number_of_elements= len(df['Cabin'])
print('Number of elements: ',number_of_elements)
print(df['Cabin'].value_counts())
df['Cabin'].fillna('G6',inplace=True)
df.tail()
# Out:
# Number of elements:  891
# C23 C25 C27    4
# B96 B98        4
# G6             4
# F2             3
# E101           3
#               ..
# B79            1
# D48            1
# A24            1
# E31            1
# C70            1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
# ...

# %%
 import seaborn as sns
sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x="Sex", y="Age", data=df)

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)

# %%
df['Survived'] = df.index

# %%
print(type(df.groupby('Pclass').mean()))
df.groupby('Pclass').mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         PassengerId    Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  486.648148  37.048118  0.416667  0.356481  84.154687
# 2        445.956522  426.826087  29.866958  0.402174  0.380435  20.662183
# 3        439.154786  433.488798  26.403259  0.615071  0.393075  13.675550

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":         "Officier",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         1       3
# 2            641         2       3
# 3            568         3       3
# 4            672         4       1
# ..           ...       ...     ...
# 886           10       886       2
# 887           61       887       3
# 888          535       888       3
# 889          102       889       3
# 890          428       890       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['Title'] = df.index

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         1       3
# 2            641         2       3
# 3            568         3       3
# 4            672         4       1
# ..           ...       ...     ...
# 886           10       886       2
# 887           61       887       3
# 888          535       888       3
# 889          102       889       3
# 890          428       890       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
i = 0
for date, row in df.T.iteritems():
    name = row["Name"]
    for title in Title_Dictionary.keys():
        if title in name:
            print(title)
            df.loc[i,"Title"] = title
            i+=1
df
# Out:
# Col
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mrs
# Mr
# Miss
# Mr
# Mrs
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mr
# Mr
# Dr
# Mr
# Miss
# Mr
# Mr
# Mr
# Major
# Mr
# Mrs
# Don
# Mr
# Mr
# Col
# Mr
# Miss
# Miss
# Mr
# Mr
# Miss
# Mr
# Miss
# Mr
# Master
# Dr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mr
# Mrs
# Miss
# Miss
# Master
# Miss
# Mr
# Rev
# Mr
# Mr
# Mrs
# Mr
# Mrs
# Miss
# Mr
# Mr
# Mrs
# Mr
# Mr
# Miss
# Mr
# Miss
# Miss
# Miss
# Mr
# Mrs
# Master
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Mr
# Mrs
# Mr
# Mrs
# Miss
# Mr
# Mrs
# Mr
# Mr
# Dr
# Mr
# Miss
# Mr
# Mrs
# Mr
# Mr
# Mr
# Master
# Mr
# Mr
# Mr
# Mr
# Mr
# Mrs
# Miss
# Mr
# Mr
# Master
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Col
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Mr
# Miss
# Mr
# Mr
# Miss
# Mr
# Mr
# Mrs
# Miss
# Mr
# Miss
# Mr
# Mrs
# Miss
# Mr
# Mr
# Mr
# Mr
# Mrs
# Mr
# Miss
# Mr
# Mrs
# Mr
# Miss
# Mr
# Mr
# Mrs
# Miss
# ...
